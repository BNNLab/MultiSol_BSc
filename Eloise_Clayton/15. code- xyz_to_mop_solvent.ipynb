# %%
import os
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem

df = pd.read_csv("filtered_solvent_data.csv")  

# Extract unique solvent names and SMILES
unique_solvents = df[['solvent_name', 'solvent_smiles']].drop_duplicates().dropna()

# Create output directory
output_dir = "xyz_files_solvent"
os.makedirs(output_dir, exist_ok=True)

# Function to generate XYZ coordinates from SMILES
def smiles_to_xyz(smiles, solvent_name):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        print(f"❌ Failed to convert SMILES for solvent: {solvent_name}")
        return None

    mol = Chem.AddHs(mol)  # Add Hydrogens

    # Generate 3D coordinates
    if AllChem.EmbedMolecule(mol, AllChem.ETKDG()) != 0:
        print(f"⚠️ Embedding failed for solvent: {solvent_name}")
        return None

    AllChem.UFFOptimizeMolecule(mol)  # Optimize geometry

    # Extract XYZ Coordinates
    conf = mol.GetConformer()
    xyz_data = [f"{mol.GetNumAtoms()}", f"Solvent: {solvent_name}"]  

    for i, atom in enumerate(mol.GetAtoms()):
        pos = conf.GetAtomPosition(i)
        xyz_data.append(f"{atom.GetSymbol()} {pos.x:.4f} {pos.y:.4f} {pos.z:.4f}")

    return "\n".join(xyz_data)

# Loop through unique solvents and generate XYZ files
for _, row in unique_solvents.iterrows():
    solvent_name = row["solvent_name"].replace(" ", "_")  
    smiles = row["solvent_smiles"]

    xyz_content = smiles_to_xyz(smiles, solvent_name)
    if xyz_content:
        xyz_filename = os.path.join(output_dir, f"{solvent_name}.xyz")
        with open(xyz_filename, "w") as xyz_file:
            xyz_file.write(xyz_content)
        print(f"✅ XYZ file saved: {xyz_filename}")
# Out:
# ✅ XYZ file saved: xyz_files_solvent/1,2-dichloroethane.xyz
# ✅ XYZ file saved: xyz_files_solvent/1,2-propanediol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1,4-dioxane.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-chlorobutane.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-chlorooctane.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-decanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-decanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-heptanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-heptanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-hexanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-hexanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-octanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-octanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-pentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-pentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/1-tert-butoxy-2-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2,2,4-trimethylpentane.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-butoxyethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-ethoxyethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-ethyl-1-hexanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-isopropoxyethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-1-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-1-pentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-1-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-1-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-2-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-2-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-methyl-2-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-pentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-propanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/2-propoxyethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/3-methoxy-1-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/3-methyl-1-butanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/4-methyl-2-pentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/DMF.xyz
# ✅ XYZ file saved: xyz_files_solvent/DMF.xyz
# ✅ XYZ file saved: xyz_files_solvent/DMF.xyz
# ✅ XYZ file saved: xyz_files_solvent/DMSO.xyz
# ✅ XYZ file saved: xyz_files_solvent/DMSO.xyz
# ✅ XYZ file saved: xyz_files_solvent/N-methyl-2-pyrrolidone.xyz
# ✅ XYZ file saved: xyz_files_solvent/N-methyl-2-pyrrolidone.xyz
# ✅ XYZ file saved: xyz_files_solvent/N-methylformamide.xyz
# ✅ XYZ file saved: xyz_files_solvent/PEG400.xyz
# ✅ XYZ file saved: xyz_files_solvent/PEG400.xyz
# ✅ XYZ file saved: xyz_files_solvent/THF.xyz
# ✅ XYZ file saved: xyz_files_solvent/THF.xyz
# ✅ XYZ file saved: xyz_files_solvent/THF.xyz
# ✅ XYZ file saved: xyz_files_solvent/THF.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetic_acid.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetic_acid.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetone.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetone.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetonitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetonitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetonitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/acetophenone.xyz
# ✅ XYZ file saved: xyz_files_solvent/aniline.xyz
# ✅ XYZ file saved: xyz_files_solvent/benzene.xyz
# ✅ XYZ file saved: xyz_files_solvent/benzene.xyz
# ✅ XYZ file saved: xyz_files_solvent/benzyl_alcohol.xyz
# ✅ XYZ file saved: xyz_files_solvent/butanone.xyz
# ✅ XYZ file saved: xyz_files_solvent/butanone.xyz
# ✅ XYZ file saved: xyz_files_solvent/butyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/butyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/butyronitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/butyronitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/carbon_disulfide.xyz
# ✅ XYZ file saved: xyz_files_solvent/carbon_disulfide.xyz
# ✅ XYZ file saved: xyz_files_solvent/carbon_tetrachloride.xyz
# ✅ XYZ file saved: xyz_files_solvent/carbon_tetrachloride.xyz
# ✅ XYZ file saved: xyz_files_solvent/carbon_tetrachloride.xyz
# ✅ XYZ file saved: xyz_files_solvent/chlorobenzene.xyz
# ✅ XYZ file saved: xyz_files_solvent/chlorobenzene.xyz
# ✅ XYZ file saved: xyz_files_solvent/chlorocyclohexane.xyz
# ✅ XYZ file saved: xyz_files_solvent/chloroform.xyz
# ✅ XYZ file saved: xyz_files_solvent/chloroform.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclohexane.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclohexanone.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclohexanone.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclohexanone.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclooctane.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclopentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/cyclopentanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/decane.xyz
# ✅ XYZ file saved: xyz_files_solvent/decane.xyz
# ✅ XYZ file saved: xyz_files_solvent/dibutyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/dibutyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/dichloroethane.xyz
# ✅ XYZ file saved: xyz_files_solvent/dichloromethane.xyz
# ✅ XYZ file saved: xyz_files_solvent/dichloromethane.xyz
# ✅ XYZ file saved: xyz_files_solvent/diethyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/diethyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/diisopropyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/diisopropyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/dimethylacetamide.xyz
# ✅ XYZ file saved: xyz_files_solvent/dimethylacetamide.xyz
# ✅ XYZ file saved: xyz_files_solvent/dodecane.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethylbenzene.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethylene_glycol.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethylene_glycol.xyz
# ✅ XYZ file saved: xyz_files_solvent/ethylene_glycol.xyz
# ✅ XYZ file saved: xyz_files_solvent/formamide.xyz
# ✅ XYZ file saved: xyz_files_solvent/heptane.xyz
# ✅ XYZ file saved: xyz_files_solvent/hexadecane.xyz
# ✅ XYZ file saved: xyz_files_solvent/hexane.xyz
# ✅ XYZ file saved: xyz_files_solvent/m-xylene.xyz
# ✅ XYZ file saved: xyz_files_solvent/methanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/methanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/methyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/methyl_tert-butyl_ether.xyz
# ✅ XYZ file saved: xyz_files_solvent/methylcyclohexane.xyz
# ✅ XYZ file saved: xyz_files_solvent/nitromethane.xyz
# ✅ XYZ file saved: xyz_files_solvent/nitromethane.xyz
# ✅ XYZ file saved: xyz_files_solvent/nonane.xyz
# ✅ XYZ file saved: xyz_files_solvent/o-xylene.xyz
# ✅ XYZ file saved: xyz_files_solvent/octane.xyz
# ✅ XYZ file saved: xyz_files_solvent/octane.xyz
# ✅ XYZ file saved: xyz_files_solvent/p-xylene.xyz
# ✅ XYZ file saved: xyz_files_solvent/pentyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/propionitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/propionitrile.xyz
# ✅ XYZ file saved: xyz_files_solvent/propyl_acetate.xyz
# ✅ XYZ file saved: xyz_files_solvent/propylene_carbonate.xyz
# ✅ XYZ file saved: xyz_files_solvent/propylene_carbonate.xyz
# ✅ XYZ file saved: xyz_files_solvent/propylene_carbonate.xyz
# ✅ XYZ file saved: xyz_files_solvent/propylene_carbonate.xyz
# ✅ XYZ file saved: xyz_files_solvent/propylene_glycol.xyz
# ✅ XYZ file saved: xyz_files_solvent/propylene_glycol.xyz
# ✅ XYZ file saved: xyz_files_solvent/sulfolane.xyz
# ✅ XYZ file saved: xyz_files_solvent/tert-butylcyclohexane.xyz
# ✅ XYZ file saved: xyz_files_solvent/toluene.xyz
# ✅ XYZ file saved: xyz_files_solvent/toluene.xyz
# ✅ XYZ file saved: xyz_files_solvent/toluene.xyz
# ✅ XYZ file saved: xyz_files_solvent/trifluoroethanol.xyz
# ✅ XYZ file saved: xyz_files_solvent/undecane.xyz
# ✅ XYZ file saved: xyz_files_solvent/water.xyz

# %%
import os

xyz_dir = "xyz_files_solvent"  
output_dir = "xyz_to_mop_solvent" 

os.makedirs(output_dir, exist_ok=True)

# Define the MOPAC header
mop_header = "AUX LARGE OPT FORCE THERMO PM6-D3H4X T=128H RECALC=5 GNORM=0.01 LET SCFCRT=0.0000001\n"

# Process each XYZ file
for filename in os.listdir(xyz_dir):
    if filename.endswith(".xyz"):
        input_path = os.path.join(xyz_dir, filename)
        
        # Change the extension from .xyz to .mop
        new_filename = filename.replace(".xyz", ".mop")
        output_path = os.path.join(output_dir, new_filename)
        
        # Read the existing XYZ content
        with open(input_path, "r") as file:
            lines = file.readlines()

        # Extract the filename without extension for the second line
        xyz_filename_line = filename  

        # Remove the first two lines 
        atom_lines = lines[2:]  

        # Ensure an empty line at the end
        final_content = mop_header + xyz_filename_line + "\n\n" + "".join(atom_lines) + "\n"

        # Write to a new .mop file
        with open(output_path, "w") as file:
            file.write(final_content)
        
        print(f"✅ New .mop file created: {output_path}")
# Out:
# ✅ New .mop file created: xyz_to_mop_solvent/sulfolane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/acetic_acid.mop
# ✅ New .mop file created: xyz_to_mop_solvent/propylene_glycol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/dodecane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-ethoxyethanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/m-xylene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/diethyl_ether.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-chlorooctane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/THF.mop
# ✅ New .mop file created: xyz_to_mop_solvent/ethylbenzene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/dimethylacetamide.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-butanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/butanone.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-isopropoxyethanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-methyl-1-pentanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-propoxyethanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/benzyl_alcohol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-pentanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-ethyl-1-hexanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/cyclopentanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-butoxyethanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/trifluoroethanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/acetone.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-propanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/dibutyl_ether.mop
# ✅ New .mop file created: xyz_to_mop_solvent/propionitrile.mop
# ✅ New .mop file created: xyz_to_mop_solvent/diisopropyl_ether.mop
# ✅ New .mop file created: xyz_to_mop_solvent/cyclooctane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/cyclohexanone.mop
# ✅ New .mop file created: xyz_to_mop_solvent/nonane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/dichloroethane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/chlorocyclohexane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/p-xylene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/4-methyl-2-pentanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/3-methyl-1-butanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/3-methoxy-1-butanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/hexane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/chloroform.mop
# ✅ New .mop file created: xyz_to_mop_solvent/methyl_tert-butyl_ether.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-chlorobutane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/heptane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/benzene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/butyronitrile.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1,2-propanediol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-butanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/dichloromethane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/N-methyl-2-pyrrolidone.mop
# ✅ New .mop file created: xyz_to_mop_solvent/methyl_acetate.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-octanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/hexadecane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/ethanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/DMF.mop
# ✅ New .mop file created: xyz_to_mop_solvent/octane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/propylene_carbonate.mop
# ✅ New .mop file created: xyz_to_mop_solvent/aniline.mop
# ✅ New .mop file created: xyz_to_mop_solvent/toluene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/butyl_acetate.mop
# ✅ New .mop file created: xyz_to_mop_solvent/nitromethane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/undecane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/water.mop
# ✅ New .mop file created: xyz_to_mop_solvent/PEG400.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1,4-dioxane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-tert-butoxy-2-propanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-pentanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2,2,4-trimethylpentane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-decanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/methanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/carbon_tetrachloride.mop
# ✅ New .mop file created: xyz_to_mop_solvent/ethyl_acetate.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-methyl-2-butanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/chlorobenzene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/methylcyclohexane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/decane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/formamide.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-methyl-2-propanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-heptanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/tert-butylcyclohexane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/propyl_acetate.mop
# ✅ New .mop file created: xyz_to_mop_solvent/acetophenone.mop
# ✅ New .mop file created: xyz_to_mop_solvent/o-xylene.mop
# ✅ New .mop file created: xyz_to_mop_solvent/DMSO.mop
# ✅ New .mop file created: xyz_to_mop_solvent/N-methylformamide.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-hexanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/pentyl_acetate.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1,2-dichloroethane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/cyclohexane.mop
# ✅ New .mop file created: xyz_to_mop_solvent/ethylene_glycol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-methyl-1-butanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/1-propanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/carbon_disulfide.mop
# ✅ New .mop file created: xyz_to_mop_solvent/2-methyl-1-propanol.mop
# ✅ New .mop file created: xyz_to_mop_solvent/acetonitrile.mop

# %%
import zipfile
import os

folder_path = 'xyz_to_mop_solvent'  
zip_file_name = 'xyz_to_mop_solvent.zip'  

# Create a zip file
with zipfile.ZipFile(zip_file_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            zipf.write(os.path.join(root, file), 
                       os.path.relpath(os.path.join(root, file), 
                                      os.path.join(folder_path, '..')))
