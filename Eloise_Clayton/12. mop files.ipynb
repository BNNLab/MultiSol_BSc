# %%
import os
import pandas as pd

solvent_eps = pd.read_csv("solvent_eps_csv.csv")
filtered_data = pd.read_csv("filtered_data_with_smiles.csv")

# Merge the datasets on 'solvent_name'
merged_data = filtered_data.merge(solvent_eps[['solvent_name', 'EPS']], on='solvent_name', how='left')

merged_data.to_csv("merged_data.csv", index=False)

# Set up the directory for XYZ files and the output MOP files
xyz_dir = os.path.join(os.getcwd(), "xyz_files")  
mop_dir = os.path.join(os.getcwd(), "xyz_to_mop")  
os.makedirs(mop_dir, exist_ok=True) 

# Track missing files
missing_xyz_files = []

# Loop through the merged data and create new .mop files with the correct EPS values
for index, row in merged_data.iterrows():
    solute_name = row['solute_name']
    solvent_name = row['solvent_name']
    eps_value = row['EPS']
    solute_inchikey = row['solute_inchikey']  
    
    # Skip if the EPS value is missing
    if pd.isna(eps_value):
        print(f"Skipping {solute_inchikey} because EPS value is missing.")
        continue

    rsolv_value = 1.3

    # Determine the mop filename based on the solvent type (water or gas)
    if 'water' in solvent_name.lower():  
        mop_filename = f"{solute_inchikey}_water.mop"  
    else:  
        mop_filename = f"{solute_inchikey}_{solvent_name.replace(' ', '_')}.mop"

    mop_filepath = os.path.join(mop_dir, mop_filename)

    # Look for the corresponding XYZ file based on solute InChIKey
    xyz_filename = f"{solute_inchikey}.xyz" 
    xyz_filepath = os.path.join(xyz_dir, xyz_filename)

    # If the XYZ file exists, create a new .mop file
    if os.path.exists(xyz_filepath):
        with open(xyz_filepath, 'r') as xyz_file, open(mop_filepath, 'w') as mop_file:
            
            mop_header = f"AUX LARGE OPT FORCE THERMO PM6-D3H4X T=128H RECALC=5 GNORM=0.01 LET SCFCRT=0.0000001 RSOLV={rsolv_value} EPS={eps_value}\n"
            mop_file.write(mop_header)
            mop_file.write(f"{xyz_filename}\n\n")  

            # Skip the first two lines (usually header information in the XYZ file)
            lines = xyz_file.readlines()[2:]  

            # Write the atom coordinates to the .mop file
            mop_file.writelines(lines)
            mop_file.write("\n")  # Ensure an empty line at the end

        print(f"Created {mop_filename} with EPS={eps_value} and RSOLV={rsolv_value}")
    else:
        # Track missing XYZ files
        missing_xyz_files.append(xyz_filename)
        print(f"Warning: {xyz_filename} does not exist. Skipping.")

print(f"\nTotal number of missing XYZ files: {len(missing_xyz_files)}")
print(f"Missing XYZ files: {missing_xyz_files}")
# Out:
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created NGTRZJDYCCOXBA-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created MKASXAGBWHIGCF-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created DFYRUELUNQRZTB-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created WBYWAXJHAXSJNI-KZFATGLANA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created ONUFSRWQCKNVSL-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created VHHHONWQHHHLTI-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created UFWIBTONFRDIAS-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created JDCMOHAFGDQQJX-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created GSDSWSVVBLHKDQ-LQFNOIFHNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created MWOOGOJBHIARFG-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1,2-dichloroethane.mop with EPS=10.45 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created KRKNYBCHXYNGOX-CUNNJMNPNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created DCOPUUMXTXDBNB-GPQMBLKYNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created LNEPOXFFQSENCJ-UHFFFAOYNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created JYGXADMDTFJGBT-VWUMJDOONA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created HEFNNWSXXWATRW-YHMJCDSINA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created HYYBABOKPJLUIN-HCKMINDGNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created QYSPLQLAKJAUJT-HCKMINDGNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created SEEPANYCNGTZFQ-YHMJCDSINA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_1,2-propanediol.mop with EPS=32.0 and RSOLV=1.3
# Created DWCLXOREGBLXTD-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created JZFDKGFWNSQAHU-GPQMBLKYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created XZAXQWXHBDKYJI-CMLSCEPHNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created PZPZDEIASIKHPY-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created JWAZRIHNYRIHIV-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created KFIRODWJCYBBHY-QIQUEDJNNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created BONIIQYTWOPUQI-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created GKODDAXOSGGARJ-KZFATGLANA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created HEWGVSGLMQJYHJ-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created RGGYLRDGJAJICY-ZYMSVLFVNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created WNLRTRBMVRJNCN-AUDIXQRPNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created BLFLLBZGZJTVJG-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created KRKNYBCHXYNGOX-CUNNJMNPNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created DCOPUUMXTXDBNB-GPQMBLKYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created LNEPOXFFQSENCJ-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created HEFNNWSXXWATRW-YHMJCDSINA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created HCUARRIEZVDMPT-WXRBYKJCNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created CGIGDMFJXJATDK-QWOVJGMINA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created DWMREKMVXIFPFM-RWWBHRBBNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created JZFPYUNJRRFVQU-VEWCPZSHNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created CPJSUEIXXCENMM-WXRBYKJCNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created VGEREEWJJVICBM-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created QYSPLQLAKJAUJT-HCKMINDGNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created QIQXTHQIDYTFRH-LILDFLRNNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created SEEPANYCNGTZFQ-YHMJCDSINA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created YZMCKZRAOLZXAZ-WYUMXYHSNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created PEQHIRFAKIASBK-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created ZFXYFBGIUFBOJW-FZOZFQFYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created UMGDCJDMYOKAJW-UBUOBULFNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_1,4-dioxane.mop with EPS=2.2 and RSOLV=1.3
# Created FBPFZTCFMRRESA-FBXFSONDNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created NSPMIYGKQJPBQR-TULZNQERNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created QQVIHTHCMHWDBS-FLKJISBTNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created AYIRNRDRBQJXIF-SVGYMEAUNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created LDZYRENCLPUXAX-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created SZTDSGCADFWGKM-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created NVKJOXRVEKMMHS-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created LETVJWLLIMJADE-GLFQYTTQNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created BXRFQSNOROATLV-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created DTXVKPOKPFWSFF-MDVJYLRGNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created WNLRTRBMVRJNCN-AUDIXQRPNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created BLUAFEHZUWYNDE-NNWCWBAJNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created FAOHQGXEASKQDL-AHPDCHJINA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created HYZJCKYKOHLVJF-FZOZFQFYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created QGJZLNKBHJESQX-WRDJYESVNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ROAXLGSFGIOFMH-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created QFOHBWFCKVYLES-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created JBKVHLHDHHXQEQ-QDQILVOLNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created FFGPTBGBLSHEPO-ZHLVXTBQNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created WBYWAXJHAXSJNI-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created KRKNYBCHXYNGOX-CUNNJMNPNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created HEFNNWSXXWATRW-RILOQBQWNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YSSSPARMOAYJTE-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created IYYZUPMFVPLQIF-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ROORDVPLFPIABK-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created NUVBSKCKDOMJSU-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created NJGBTKGETPDVIK-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZNNLBTZKUZBEKO-PLJOYGPPNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created LNEPOXFFQSENCJ-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created AIONOLUJZLIMTK-AWEZNQCLNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created HCUARRIEZVDMPT-WXRBYKJCNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created DNKGZSOYWMQDTK-KZFATGLANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created JTEGQNOMFQHVDC-IRNSGEEPNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created MJIHNNLFOKEZEW-PKSOQXRJNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created POULHZVOKOAJMA-NDKGDYFDNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created GSDSWSVVBLHKDQ-QVNXLTHBNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created IQPNAANSBPBGFQ-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created XPCTZQVDEJYUGT-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created DWMREKMVXIFPFM-RWWBHRBBNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZIMGGGWCDYVHOY-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created FDDDEECHVMSUSB-FSHFIPFONA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created IPCSVZSSVZVIGE-HCKMINDGNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created CPJSUEIXXCENMM-WXRBYKJCNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZQBAKBUEJOMQEX-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created VGEREEWJJVICBM-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YJGVMLPVUAXIQN-XVVDYKMHNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created QELSKZZBTMNZEB-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created IKGXIBQEEMLURG-NVPNHPEKNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created QIQXTHQIDYTFRH-LILDFLRNNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created SEEPANYCNGTZFQ-YHMJCDSINA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created ZFXYFBGIUFBOJW-FZOZFQFYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created UMGDCJDMYOKAJW-UBUOBULFNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created IEDVJHCEMCRBQM-CLRGVMNRNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1-butanol.mop with EPS=17.8 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created LDZYRENCLPUXAX-BGGKNDAXNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created HYZJCKYKOHLVJF-FZOZFQFYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-chlorobutane.mop with EPS=7.2 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created UJOBWOGCFQCDNV-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-chlorooctane.mop with EPS=5.1 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created QFOHBWFCKVYLES-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created NUVBSKCKDOMJSU-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created HEFNNWSXXWATRW-YHMJCDSINA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created QELSKZZBTMNZEB-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1-decanol.mop with EPS=8.1 and RSOLV=1.3
# Created QQVIHTHCMHWDBS-FLKJISBTNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created NVKJOXRVEKMMHS-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created MUMGGOZAMZWBJJ-DYKIIFRCNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created DNKGZSOYWMQDTK-KZFATGLANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created DWMREKMVXIFPFM-RWWBHRBBNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1-heptanol.mop with EPS=6.7 and RSOLV=1.3
# Created QQVIHTHCMHWDBS-FLKJISBTNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created LDZYRENCLPUXAX-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created NVKJOXRVEKMMHS-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created OBKXEAXTFZPCHS-WXRBYKJCNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created HYZJCKYKOHLVJF-FZOZFQFYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created QGJZLNKBHJESQX-WRDJYESVNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created QFOHBWFCKVYLES-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created NUVBSKCKDOMJSU-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created POULHZVOKOAJMA-NDKGDYFDNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created DWMREKMVXIFPFM-RWWBHRBBNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created QELSKZZBTMNZEB-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created UMGDCJDMYOKAJW-UBUOBULFNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1-hexanol.mop with EPS=13.3 and RSOLV=1.3
# Created QQVIHTHCMHWDBS-FLKJISBTNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created SWJPEBQEEAHIGZ-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created FPWNLURCHDRMHC-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created LPNBBFKOUUSUDB-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created OIGXDZJSRMPECU-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created JCLYNMPVVXQIJI-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YLYIXDZITBMCIW-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created MUMGGOZAMZWBJJ-DYKIIFRCNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created RGGYLRDGJAJICY-ZYMSVLFVNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created FZERHIULMFGESH-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created FAOHQGXEASKQDL-AHPDCHJINA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created FTOAOBMCPZCFFF-XMBMESGPNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created BLFLLBZGZJTVJG-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created IUWVALYLNVXWKX-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created QFOHBWFCKVYLES-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created RYYVLZVUVIJVGH-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created UJOBWOGCFQCDNV-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created WBYWAXJHAXSJNI-KZFATGLANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created MFYSYFVPBJMHGN-ZPOLXVRWNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created HEFNNWSXXWATRW-RILOQBQWNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created AAOVKJBEBIDNHE-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created DCOPUUMXTXDBNB-GPQMBLKYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created NUVBSKCKDOMJSU-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created LPEPZBJOKDYZAD-LILDFLRNNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created SYTBZMRGLBWNTM-HCKMINDGNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created VZCYOOQTPOCHFL-KHGLRPAFNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ZZUFCTLCJUWOSV-CDZRGBSPNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created IIUZTXTZRGLYTI-LKUJNTHKNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created VHHHONWQHHHLTI-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created JYGXADMDTFJGBT-VWUMJDOONA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created HEFNNWSXXWATRW-YHMJCDSINA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created CGIGDMFJXJATDK-QWOVJGMINA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created PCZOHLXUXFIOCF-BXMDZJJMNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created DWMREKMVXIFPFM-RWWBHRBBNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created VAOCPAMSLUNLGC-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created UFWIBTONFRDIAS-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created PVNIIMVLHYAWGP-FZOZFQFYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created JZFPYUNJRRFVQU-VEWCPZSHNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created CPJSUEIXXCENMM-WXRBYKJCNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created DDBREPKUVSBGFI-KGCNKATMNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ISWSIDIOOBJBQZ-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created QYSPLQLAKJAUJT-HCKMINDGNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created OIGNJSKKLXVSLS-VWUMJDOONA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created RJKFOVLPORLFTN-LEKSSAKUNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created QELSKZZBTMNZEB-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created SEEPANYCNGTZFQ-YHMJCDSINA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ASWVTGNCAZCNNR-WYUMXYHSNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created JLKIGFTWXXRPMT-NDKGDYFDNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created FDDDEECHVMSUSB-FSHFIPFONA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created GECHUMIMRBOMGK-YHMJCDSINA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created JNMRHUJNCSQMMB-XWKXFZRBNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YZMCKZRAOLZXAZ-WYUMXYHSNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created ZFXYFBGIUFBOJW-BGGKNDAXNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1-octanol.mop with EPS=10.3 and RSOLV=1.3
# Created QQVIHTHCMHWDBS-FLKJISBTNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created NVKJOXRVEKMMHS-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created MUMGGOZAMZWBJJ-DYKIIFRCNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created QGJZLNKBHJESQX-WRDJYESVNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created QFOHBWFCKVYLES-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created WBYWAXJHAXSJNI-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created KRKNYBCHXYNGOX-CUNNJMNPNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created HEFNNWSXXWATRW-RILOQBQWNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created DCOPUUMXTXDBNB-GPQMBLKYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created NUVBSKCKDOMJSU-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created LNEPOXFFQSENCJ-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created HEFNNWSXXWATRW-YHMJCDSINA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created DNKGZSOYWMQDTK-KZFATGLANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created MJIHNNLFOKEZEW-PKSOQXRJNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created POULHZVOKOAJMA-NDKGDYFDNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created DWMREKMVXIFPFM-RWWBHRBBNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created JZFPYUNJRRFVQU-VEWCPZSHNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created IPCSVZSSVZVIGE-HCKMINDGNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created CPJSUEIXXCENMM-WXRBYKJCNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created VGEREEWJJVICBM-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created QYSPLQLAKJAUJT-HCKMINDGNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created QELSKZZBTMNZEB-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created SEEPANYCNGTZFQ-YHMJCDSINA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created UMGDCJDMYOKAJW-UBUOBULFNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created IEDVJHCEMCRBQM-CLRGVMNRNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_1-pentanol.mop with EPS=13.9 and RSOLV=1.3
# Created FBPFZTCFMRRESA-FBXFSONDNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created NSPMIYGKQJPBQR-TULZNQERNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created QQVIHTHCMHWDBS-FLKJISBTNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created KSKWGMNRWCYVAT-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created GRWAIJBHBCCLGS-FZOZFQFYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created AYIRNRDRBQJXIF-SVGYMEAUNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created GFLHGSIWKATBCA-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created JZFDKGFWNSQAHU-GPQMBLKYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created XZAXQWXHBDKYJI-CMLSCEPHNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created SJEBAWHUJDUKQK-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created LDZYRENCLPUXAX-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created VPHHJAOJUJHJKD-KZFATGLANA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created SZTDSGCADFWGKM-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created NVKJOXRVEKMMHS-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created LETVJWLLIMJADE-GLFQYTTQNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created FPWNLURCHDRMHC-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created BXRFQSNOROATLV-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created KGCNHWXDPDPSBV-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created WHUUTDBJXJRKMK-IQTGVIGANA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created OIGXDZJSRMPECU-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created JCLYNMPVVXQIJI-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created YLYIXDZITBMCIW-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created WNLRTRBMVRJNCN-AUDIXQRPNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created DFYRUELUNQRZTB-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created SXYIRMFQILZOAM-HVNFFKDJNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created FAOHQGXEASKQDL-AHPDCHJINA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_1-propanol.mop with EPS=20.1 and RSOLV=1.3
# ...
# Created QECIGCMPORCORE-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created WLJVXDMOQOGPHL-BGGKNDAXNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created YVUQSNJEYSNKRX-VJSLDGLSNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created SATCULPHIDQDRE-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created XVULBTBTFGYVRC-HHUCQEJWNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created QIQXTHQIDYTFRH-LILDFLRNNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created WURBVZBTWMNKQT-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created MWOOGOJBHIARFG-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created WJUFSDZVCOTFON-UHFFFAOYNA-N_toluene.mop with EPS=2.4 and RSOLV=1.3
# Created BGNGWHSBYQYVRX-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created MFFDJRYGVWMCQY-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created MSWPGMRTURVKRJ-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created NQTPEBUGIFUYEC-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created UVEWQKMPXAHFST-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created FFGPTBGBLSHEPO-ZHLVXTBQNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created WBYWAXJHAXSJNI-KZFATGLANA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created XNGIFLGASWRNHJ-FLKJISBTNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created MWOOGOJBHIARFG-UHFFFAOYNA-N_trifluoroethanol.mop with EPS=26.8 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created YLQWCDOCJODRMT-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created GVIJJXMXTUZIOD-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created GJCOSYZMQJWQCA-UHFFFAOYNA-N_undecane.mop with EPS=2.0 and RSOLV=1.3
# Created NSPMIYGKQJPBQR-TULZNQERNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SWJPEBQEEAHIGZ-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created GRWAIJBHBCCLGS-FZOZFQFYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RJKGJBPXVHTNJL-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created AYIRNRDRBQJXIF-SVGYMEAUNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YBZQRYWKYBZZNT-IAUQMDSZNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DWCLXOREGBLXTD-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WXTMDXOMEHJXQO-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SKCNYHLTRZIINA-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created QUEKGYQTRJVEQC-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created XVOYSCVBGLVSOL-UDYUCESTNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ISAOCJYIOMOJEB-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ILUJQPXNXACGAN-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CDVNZMKTJIBBBV-WXRBYKJCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LDZYRENCLPUXAX-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZWLPBLYKEWSWPD-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JWAZRIHNYRIHIV-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DAUAQNGYDSHRET-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created VYWYYJYRVSBHJQ-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LULAYUGMBFYYEX-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created GPSDUZXPYCFOSQ-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created AFPHTEQTJZKQAQ-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created KFIRODWJCYBBHY-QIQUEDJNNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created HXEWMTXDBOQQKO-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ALYNCZNDIQEVRV-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DFXQXFGFOLXAPO-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created XRHGYUZYPHTUJZ-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FPWNLURCHDRMHC-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BBYDXOIZLAWGSL-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RGHHSNMVTDWUBI-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FJKROLUGYXJWQN-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created XQXPVVBIMDBYFF-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZEYHEAKUIGZSGI-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created NRPFNQUDKRYCNX-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LPNBBFKOUUSUDB-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created OTLNPYWUJOZPPA-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BTJIUGUIPKRLHP-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RXKNNAKAVAHBNK-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created OBKXEAXTFZPCHS-WXRBYKJCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created KBOPZPXVLCULAV-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WQZGKKKJIJFFOK-GASJEMHNNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created OIGXDZJSRMPECU-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JCLYNMPVVXQIJI-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YLYIXDZITBMCIW-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created MNIPYSSQXLZQLJ-UYBDAZJANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created IMMLSOUHQHJKTL-LNNLXFCONA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WTJMJAZVXNFVHB-LBOYIXSDNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YFLCNWFWKPUGTP-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created UDUNORRTIFRHKX-LBOYIXSDNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CWRYPZZKDGJXCA-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YASYVMFAVPKPKE-JSWHHWTPNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created KKKDZZRICRFGSD-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RZVAJINKPMORJF-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FZERHIULMFGESH-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BSYNRYMUTXBXSQ-WXRBYKJCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WNLRTRBMVRJNCN-AUDIXQRPNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created MWPLVEDNUUSJAV-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RZVHIXYEVGDQDX-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CIWBSHSKHKDKBQ-JLAZNSOCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FAOHQGXEASKQDL-AHPDCHJINA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FTOAOBMCPZCFFF-XMBMESGPNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WURBFLDFSFBTLW-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BLFLLBZGZJTVJG-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WPYMKLBDIGXBTP-FZOZFQFYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RWCCWEUUXYIKHB-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created AZQWKYJCGOJGHM-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZUOUZKKEUPVFJK-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created VRPJIFMKZZEXLR-DEPUQRHONA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created IUWVALYLNVXWKX-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created QFOHBWFCKVYLES-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RYYVLZVUVIJVGH-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FFGPTBGBLSHEPO-ZHLVXTBQNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created UJOBWOGCFQCDNV-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZPSPULCZMWMHCY-GHUVFRGKNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BOCJQSFSGAZAPQ-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created HVYWMOMLDIMFJA-DPAQBDIFNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created AQIXAKUUQRKLND-CJFCUXRANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WBYWAXJHAXSJNI-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created KRKNYBCHXYNGOX-CUNNJMNPNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DGBIGWXXNGSACT-GPQMBLKYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created MFYSYFVPBJMHGN-ZPOLXVRWNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LDHQCZJRKDOVOX-GSMIJIFMNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created AAOVKJBEBIDNHE-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created IYYZUPMFVPLQIF-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DCOPUUMXTXDBNB-GPQMBLKYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created NOCJXYPHIIZEHN-LBOYIXSDNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created HUPFGZXOMWLGNK-HCKMINDGNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LDCRTTXIJACKKU-ONEGZZNKNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WQLVFSAGQJTQCK-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created KZTYYGOKRVBIMI-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PYHXGXCGESYPCW-YAQRNVERNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created XMTQQYYKAHVGBJ-XWKXFZRBNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SQNZJJAZBFDUTD-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created NUVBSKCKDOMJSU-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LPEPZBJOKDYZAD-LILDFLRNNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created GVEPBJHOBDJJJI-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created NIHNNTQXNPWCJQ-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SYTBZMRGLBWNTM-HCKMINDGNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created VZCYOOQTPOCHFL-AOTPWWKUNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZZUFCTLCJUWOSV-CDZRGBSPNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DDUHZTYCFQRHIY-RBHXEPJQNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LNEPOXFFQSENCJ-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created AIONOLUJZLIMTK-AWEZNQCLNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CKAPSXZOOQJIBF-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created VHHHONWQHHHLTI-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JYGXADMDTFJGBT-VWUMJDOONA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created HEFNNWSXXWATRW-YHMJCDSINA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created OLOOJGVNMBJLLR-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created HCUARRIEZVDMPT-WXRBYKJCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CGIGDMFJXJATDK-QWOVJGMINA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created QRXWMOHMRWLFEY-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LVHBHZANLOWSRM-HJYFZBQUNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DKYWVDODHFEZIM-GPQMBLKYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JTEGQNOMFQHVDC-IRNSGEEPNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PYZRQGJRPPTADH-KGJHZMDYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created POULHZVOKOAJMA-NDKGDYFDNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PCZOHLXUXFIOCF-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created IWYDHOAUDWTVEP-KZFATGLANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created HYYBABOKPJLUIN-HCKMINDGNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZRVUJXDFFKFLMG-WYUMXYHSNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LXCFILQKKLGQFO-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created VAOCPAMSLUNLGC-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZFMITUMMTDLWHR-QMLCPYSLNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BMLIZLVNXIYGCK-WXRBYKJCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created UFWIBTONFRDIAS-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CMWTZPSULFXXJA-GTNTULIANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PVNIIMVLHYAWGP-FZOZFQFYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JZFPYUNJRRFVQU-VEWCPZSHNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created OGJPXUAPXNRGGI-QWOVJGMINA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created GSDSWSVVBLHKDQ-LQFNOIFHNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RCINICONZNJXQF-GXKQXQCDNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created IPCSVZSSVZVIGE-HCKMINDGNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created CPJSUEIXXCENMM-WXRBYKJCNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YNPNZTXNASCQKK-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created DDBREPKUVSBGFI-LUXCBXFANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ISWSIDIOOBJBQZ-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WJFKNYWRSNBZNX-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZQBAKBUEJOMQEX-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WLJVXDMOQOGPHL-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created XNGIFLGASWRNHJ-FLKJISBTNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WLJVNTCWHIRURA-PSPNOWEWNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SATCULPHIDQDRE-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created LDJVNWFKNMYYNT-IOOLVGRHNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created OIGNJSKKLXVSLS-VWUMJDOONA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created RJKFOVLPORLFTN-LEKSSAKUNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created QELSKZZBTMNZEB-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BBEAQIROQSPTKN-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SKZKKFZAGNVIMN-FSHFIPFONA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YGSDEFSMJLZEOE-BGGKNDAXNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PCMORTLOPMLEFB-VENOTMPWNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created QIQXTHQIDYTFRH-LILDFLRNNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created TYFQFVWCELRYAO-FLKJISBTNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created KDYFGRWQOYBRFD-AOTPWWKUNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created SEEPANYCNGTZFQ-YHMJCDSINA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ASWVTGNCAZCNNR-WYUMXYHSNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JLKIGFTWXXRPMT-NDKGDYFDNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created VLYWMPOKSSWJAL-YAQRNVERNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created FDDDEECHVMSUSB-FSHFIPFONA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created GECHUMIMRBOMGK-YHMJCDSINA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created JNMRHUJNCSQMMB-XWKXFZRBNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YZMCKZRAOLZXAZ-WYUMXYHSNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created BGRJTUBHPOOWDU-QDYITYEQNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WZWYJBNHTWCXIM-ZTGFOJEANA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PEQHIRFAKIASBK-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created ZFXYFBGIUFBOJW-FZOZFQFYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created YRHRIQCWCFGUEQ-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created UMGDCJDMYOKAJW-UBUOBULFNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created PJANXHGTPQOBST-VAWYXSNFNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created IEDVJHCEMCRBQM-CLRGVMNRNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created XSQUKJJJFZCRTK-UBUOBULFNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created MWOOGOJBHIARFG-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
# Created WJUFSDZVCOTFON-UHFFFAOYNA-N_water.mop with EPS=78.4 and RSOLV=1.3
#
# Total number of missing XYZ files: 0
# Missing XYZ files: []
